# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here apart from blacklisted packages that interfere with Deepnote (see above).
# if test -f requirements.txt
#   then
#     sed -i '/jedi/d;/jupyter/d;' ./requirements.txt
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install. This is the case with most projects."
# fi
# Out:
# Collecting cryptocmd==0.6.1
#   Downloading cryptocmd-0.6.1-py3-none-any.whl (8.5 kB)
# Collecting statsmodels==0.14.0
#   Downloading statsmodels-0.14.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 51.2 MB/s eta 0:00:00
# Collecting skforecast==0.8.1
#   Downloading skforecast-0.8.1-py2.py3-none-any.whl (386 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 KB 46.3 MB/s eta 0:00:00
# Collecting lightgbm==3.3.5
#   Downloading lightgbm-3.3.5-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 94.9 MB/s eta 0:00:00
# Collecting ipywidgets
#   Downloading ipywidgets-8.0.7-py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 KB 34.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in /shared-libs/python3.9/py/lib/python3.9/site-packages (from cryptocmd==0.6.1->-r ./requirements.txt (line 1)) (2.28.1)
# Collecting tablib
#   Downloading tablib-3.5.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 KB 12.1 MB/s eta 0:00:00
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 KB 41.3 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from statsmodels==0.14.0->-r ./requirements.txt (line 2)) (21.3)
# Requirement already satisfied: pandas>=1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.14.0->-r ./requirements.txt (line 2)) (1.2.5)
# Requirement already satisfied: numpy>=1.18 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.14.0->-r ./requirements.txt (line 2)) (1.23.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.14.0->-r ./requirements.txt (line 2)) (1.9.3)
# Requirement already satisfied: joblib<1.3.0,>=1.1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from skforecast==0.8.1->-r ./requirements.txt (line 3)) (1.2.0)
# Requirement already satisfied: tqdm<4.65,>=4.57.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from skforecast==0.8.1->-r ./requirements.txt (line 3)) (4.64.1)
# Requirement already satisfied: scikit-learn<1.3,>=1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from skforecast==0.8.1->-r ./requirements.txt (line 3)) (1.1.2)
# Collecting optuna<3.2,>=2.10.0
#   Downloading optuna-3.1.1-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 KB 45.8 MB/s eta 0:00:00
# Requirement already satisfied: wheel in /usr/local/lib/python3.9/site-packages (from lightgbm==3.3.5->-r ./requirements.txt (line 4)) (0.40.0)
# Requirement already satisfied: ipython>=6.1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets->-r ./requirements.txt (line 5)) (8.5.0)
# Collecting widgetsnbextension~=4.0.7
#   Downloading widgetsnbextension-4.0.8-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 67.5 MB/s eta 0:00:00
# Requirement already satisfied: ipykernel>=4.5.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets->-r ./requirements.txt (line 5)) (6.16.1)
# Collecting jupyterlab-widgets~=3.0.7
#   Downloading jupyterlab_widgets-3.0.8-py3-none-any.whl (214 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.0/215.0 KB 34.0 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.3.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipywidgets->-r ./requirements.txt (line 5)) (5.5.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 5)) (7.4.3)
# Requirement already satisfied: debugpy>=1.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 5)) (1.6.3)
# Requirement already satisfied: pyzmq>=17 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 5)) (24.0.1)
# Requirement already satisfied: nest-asyncio in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 5)) (1.5.6)
# Requirement already satisfied: matplotlib-inline>=0.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 5)) (0.1.6)
# Requirement already satisfied: tornado>=6.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 5)) (6.2)
# Requirement already satisfied: psutil in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 5)) (5.9.3)
# Requirement already satisfied: decorator in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 5)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 5)) (0.17.2)
# Requirement already satisfied: pickleshare in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 5)) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 5)) (4.8.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 5)) (3.0.31)
# Requirement already satisfied: pygments>=2.4.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 5)) (2.13.0)
# Requirement already satisfied: stack-data in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 5)) (0.5.1)
# Requirement already satisfied: backcall in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from optuna<3.2,>=2.10.0->skforecast==0.8.1->-r ./requirements.txt (line 3)) (1.4.42)
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting cmaes>=0.9.1
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Collecting PyYAML
#   Downloading PyYAML-6.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (661 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.8/661.8 KB 37.4 MB/s eta 0:00:00
# Requirement already satisfied: alembic>=1.5.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from optuna<3.2,>=2.10.0->skforecast==0.8.1->-r ./requirements.txt (line 3)) (1.11.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=21.3->statsmodels==0.14.0->-r ./requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas>=1.0->statsmodels==0.14.0->-r ./requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=1.0->statsmodels==0.14.0->-r ./requirements.txt (line 2)) (2022.5)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels==0.14.0->-r ./requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from scikit-learn<1.3,>=1.0->skforecast==0.8.1->-r ./requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests->cryptocmd==0.6.1->-r ./requirements.txt (line 1)) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from requests->cryptocmd==0.6.1->-r ./requirements.txt (line 1)) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->cryptocmd==0.6.1->-r ./requirements.txt (line 1)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from requests->cryptocmd==0.6.1->-r ./requirements.txt (line 1)) (3.4)
# Requirement already satisfied: Mako in /shared-libs/python3.9/py/lib/python3.9/site-packages (from alembic>=1.5.0->optuna<3.2,>=2.10.0->skforecast==0.8.1->-r ./requirements.txt (line 3)) (1.2.4)
# Requirement already satisfied: typing-extensions>=4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from alembic>=1.5.0->optuna<3.2,>=2.10.0->skforecast==0.8.1->-r ./requirements.txt (line 3)) (4.4.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 5)) (0.7.1)
# Requirement already satisfied: entrypoints in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 5)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->-r ./requirements.txt (line 5)) (4.11.2)
# Requirement already satisfied: ptyprocess>=0.5 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 5)) (0.7.0)
# Requirement already satisfied: wcwidth in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 5)) (0.2.5)
# Requirement already satisfied: greenlet!=0.4.17 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from sqlalchemy>=1.3.0->optuna<3.2,>=2.10.0->skforecast==0.8.1->-r ./requirements.txt (line 3)) (1.1.3.post0)
# Requirement already satisfied: executing in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 5)) (1.1.1)
# Requirement already satisfied: pure-eval in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 5)) (0.2.2)
# Requirement already satisfied: asttokens in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 5)) (2.0.8)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from Mako->alembic>=1.5.0->optuna<3.2,>=2.10.0->skforecast==0.8.1->-r ./requirements.txt (line 3)) (2.0.0)
# Installing collected packages: widgetsnbextension, tablib, PyYAML, patsy, jupyterlab-widgets, colorlog, cmaes, cryptocmd, statsmodels, optuna, lightgbm, skforecast, ipywidgets
# Successfully installed PyYAML-6.0 cmaes-0.9.1 colorlog-6.7.0 cryptocmd-0.6.1 ipywidgets-8.0.7 jupyterlab-widgets-3.0.8 lightgbm-3.3.5 optuna-3.1.1 patsy-0.5.3 skforecast-0.8.1 statsmodels-0.14.0 tablib-3.5.0 widgetsnbextension-4.0.8
# WARNING: You are using pip version 22.0.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=79771423-6114-43de-9715-d85a6acef811' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
